# %%
#titulo: SHP
#fecha: 03 DE JUNIO
#Autor: Angel De Jesus Mtz Rdz

# %%
#importamos las librerias
import pandas as pd

# %%
clientes = pd.DataFrame({
    "nombre":[
        "Juan",
        "Maria",
        "Pedro",
        "Ana",
        "Luis"
    ],
    "ciudad":[
        "Cordoba",
        "Orizaba",
        "Fortin",
        "Yanga",
        "Cuitlahuac"
    ],
    "edad":[25,30,40,35,22]
})

clientes.to_csv("clientes.csv", index=False)

clientes
# Out:
#   nombre      ciudad  edad
# 0   Juan     Cordoba    25
# 1  Maria     Orizaba    30
# 2  Pedro      Fortin    40
# 3    Ana       Yanga    35
# 4   Luis  Cuitlahuac    22

# %%
productos = pd.DataFrame({
    "producto":[
        "Laptop",
        "Mouse",
        "Teclado",
        "Monitor",
        "Impresora"
    ],
    "categoria":[
        "Tecnologia",
        "Tecnologia",
        "Tecnologia",
        "Tecnologia",
        "Tecnologia"
    ]
})

productos.to_csv("productos.csv", index=False)

productos
# Out:
#     producto   categoria
# 0     Laptop  Tecnologia
# 1      Mouse  Tecnologia
# 2    Teclado  Tecnologia
# 3    Monitor  Tecnologia
# 4  Impresora  Tecnologia

# %%
import random

ventas = pd.DataFrame({
    "id_cliente":[random.randint(1,5) for _ in range(100)],
    "id_producto":[random.randint(1,5) for _ in range(100)],
    "cantidad":[random.randint(1,10) for _ in range(100)],
    "total":[random.randint(100,15000) for _ in range(100)]
})

ventas.to_csv("ventas.csv", index=False)

ventas.head()
# Out:
#    id_cliente  id_producto  cantidad  total
# 0           2            3         8   2784
# 1           4            1         9  12089
# 2           4            4         3   4526
# 3           3            4         5  10677
# 4           4            1         6   8537

# %%
import sqlalchemy

# %%
import psycopg2

# %%
#!pip install psycopg2-binary

# %%
import psycopg2

print("psycopg2 instalado correctamente")
# Out:
# psycopg2 instalado correctamente

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql://postgres:JESUSMTZ@localhost:5432/ventas"
)

print("Conexión creada")
# Out:
# Conexión creada

# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    database="dw_ventas",
    user="postgres",
    password="JESUSMTZ"
)

print("Conexión exitosa")
# Out:
# Conexión exitosa

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:JESUSMTZ@localhost:5432/dw_ventas"
)

print("Conexión creada")
# Out:
# Conexión creada

# %%
import pandas as pd

pd.read_sql("SELECT version();", engine)
# Out:
#                                              version
# 0  PostgreSQL 15.2, compiled by Visual C++ build ...

# %%
clientes = pd.read_csv("clientes.csv")

clientes.to_sql(
    "dim_cliente",
    engine,
    if_exists="append",
    index=False
)

print("Clientes cargados correctamente")
# Out:
# Clientes cargados correctamente

# %%
pd.read_sql(
    "SELECT * FROM dim_cliente",
    engine
)
# Out:
#     id_cliente nombre      ciudad  edad
# 0            1   Juan     Cordoba    25
# 1            2  Maria     Orizaba    30
# 2            3  Pedro      Fortin    40
# 3            4    Ana       Yanga    35
# 4            5   Luis  Cuitlahuac    22
# 5            6   Juan     Cordoba    25
# 6            7  Maria     Orizaba    30
# 7            8  Pedro      Fortin    40
# 8            9    Ana       Yanga    35
# 9           10   Luis  Cuitlahuac    22
# 10          11   Juan     Cordoba    25
# 11          12  Maria     Orizaba    30
# 12          13  Pedro      Fortin    40
# 13          14    Ana       Yanga    35
# 14          15   Luis  Cuitlahuac    22
# 15          16   Juan     Cordoba    25
# 16          17  Maria     Orizaba    30
# 17          18  Pedro      Fortin    40
# 18          19    Ana       Yanga    35
# 19          20   Luis  Cuitlahuac    22
# 20          21   Juan     Cordoba    25
# 21          22  Maria     Orizaba    30
# 22          23  Pedro      Fortin    40
# 23          24    Ana       Yanga    35
# 24          25   Luis  Cuitlahuac    22
# 25          26   Juan     Cordoba    25
# 26          27  Maria     Orizaba    30
# 27          28  Pedro      Fortin    40
# 28          29    Ana       Yanga    35
# 29          30   Luis  Cuitlahuac    22
# 30          31   Juan     Cordoba    25
# 31          32  Maria     Orizaba    30
# 32          33  Pedro      Fortin    40
# 33          34    Ana       Yanga    35
# 34          35   Luis  Cuitlahuac    22
# 35          36   Juan     Cordoba    25
# 36          37  Maria     Orizaba    30
# 37          38  Pedro      Fortin    40
# 38          39    Ana       Yanga    35
# 39          40   Luis  Cuitlahuac    22

# %%
clientes = pd.read_csv("clientes.csv")

clientes.to_sql(
    "dim_cliente",
    engine,
    if_exists="append",
    index=False
)

print("Clientes cargados correctamente")
# Out:
# Clientes cargados correctamente

# %%
pd.read_sql(
    "SELECT * FROM dim_cliente",
    engine
)
# Out:
#     id_cliente nombre      ciudad  edad
# 0            1   Juan     Cordoba    25
# 1            2  Maria     Orizaba    30
# 2            3  Pedro      Fortin    40
# 3            4    Ana       Yanga    35
# 4            5   Luis  Cuitlahuac    22
# 5            6   Juan     Cordoba    25
# 6            7  Maria     Orizaba    30
# 7            8  Pedro      Fortin    40
# 8            9    Ana       Yanga    35
# 9           10   Luis  Cuitlahuac    22
# 10          11   Juan     Cordoba    25
# 11          12  Maria     Orizaba    30
# 12          13  Pedro      Fortin    40
# 13          14    Ana       Yanga    35
# 14          15   Luis  Cuitlahuac    22
# 15          16   Juan     Cordoba    25
# 16          17  Maria     Orizaba    30
# 17          18  Pedro      Fortin    40
# 18          19    Ana       Yanga    35
# 19          20   Luis  Cuitlahuac    22
# 20          21   Juan     Cordoba    25
# 21          22  Maria     Orizaba    30
# 22          23  Pedro      Fortin    40
# 23          24    Ana       Yanga    35
# 24          25   Luis  Cuitlahuac    22
# 25          26   Juan     Cordoba    25
# 26          27  Maria     Orizaba    30
# 27          28  Pedro      Fortin    40
# 28          29    Ana       Yanga    35
# 29          30   Luis  Cuitlahuac    22
# 30          31   Juan     Cordoba    25
# 31          32  Maria     Orizaba    30
# 32          33  Pedro      Fortin    40
# 33          34    Ana       Yanga    35
# 34          35   Luis  Cuitlahuac    22
# 35          36   Juan     Cordoba    25
# 36          37  Maria     Orizaba    30
# 37          38  Pedro      Fortin    40
# 38          39    Ana       Yanga    35
# 39          40   Luis  Cuitlahuac    22
# 40          41   Juan     Cordoba    25
# 41          42  Maria     Orizaba    30
# 42          43  Pedro      Fortin    40
# 43          44    Ana       Yanga    35
# 44          45   Luis  Cuitlahuac    22

# %%
clientes = pd.read_csv("clientes.csv")

clientes.to_sql(
    "dim_cliente",
    engine,
    if_exists="append",
    index=False
)
# Out:
# 5

# %%
pd.read_sql(
    "SELECT * FROM dim_cliente",
    engine
)
# Out:
#     id_cliente nombre      ciudad  edad
# 0            1   Juan     Cordoba    25
# 1            2  Maria     Orizaba    30
# 2            3  Pedro      Fortin    40
# 3            4    Ana       Yanga    35
# 4            5   Luis  Cuitlahuac    22
# 5            6   Juan     Cordoba    25
# 6            7  Maria     Orizaba    30
# 7            8  Pedro      Fortin    40
# 8            9    Ana       Yanga    35
# 9           10   Luis  Cuitlahuac    22
# 10          11   Juan     Cordoba    25
# 11          12  Maria     Orizaba    30
# 12          13  Pedro      Fortin    40
# 13          14    Ana       Yanga    35
# 14          15   Luis  Cuitlahuac    22
# 15          16   Juan     Cordoba    25
# 16          17  Maria     Orizaba    30
# 17          18  Pedro      Fortin    40
# 18          19    Ana       Yanga    35
# 19          20   Luis  Cuitlahuac    22
# 20          21   Juan     Cordoba    25
# 21          22  Maria     Orizaba    30
# 22          23  Pedro      Fortin    40
# 23          24    Ana       Yanga    35
# 24          25   Luis  Cuitlahuac    22
# 25          26   Juan     Cordoba    25
# 26          27  Maria     Orizaba    30
# 27          28  Pedro      Fortin    40
# 28          29    Ana       Yanga    35
# 29          30   Luis  Cuitlahuac    22
# 30          31   Juan     Cordoba    25
# 31          32  Maria     Orizaba    30
# 32          33  Pedro      Fortin    40
# 33          34    Ana       Yanga    35
# 34          35   Luis  Cuitlahuac    22
# 35          36   Juan     Cordoba    25
# 36          37  Maria     Orizaba    30
# 37          38  Pedro      Fortin    40
# 38          39    Ana       Yanga    35
# 39          40   Luis  Cuitlahuac    22
# 40          41   Juan     Cordoba    25
# 41          42  Maria     Orizaba    30
# 42          43  Pedro      Fortin    40
# 43          44    Ana       Yanga    35
# 44          45   Luis  Cuitlahuac    22
# 45          46   Juan     Cordoba    25
# 46          47  Maria     Orizaba    30
# 47          48  Pedro      Fortin    40
# 48          49    Ana       Yanga    35
# 49          50   Luis  Cuitlahuac    22

# %%
productos = pd.read_csv("productos.csv")

productos.to_sql(
    "dim_producto",
    engine,
    if_exists="append",
    index=False
)

print("Productos cargados correctamente")
# Out:
# Productos cargados correctamente

# %%
pd.read_sql(
    "SELECT * FROM dim_producto",
    engine
)
# Out:
#     id_producto   producto   categoria
# 0             1     Laptop  Tecnologia
# 1             2      Mouse  Tecnologia
# 2             3    Teclado  Tecnologia
# 3             4    Monitor  Tecnologia
# 4             5  Impresora  Tecnologia
# 5             6     Laptop  Tecnologia
# 6             7      Mouse  Tecnologia
# 7             8    Teclado  Tecnologia
# 8             9    Monitor  Tecnologia
# 9            10  Impresora  Tecnologia
# 10           11     Laptop  Tecnologia
# 11           12      Mouse  Tecnologia
# 12           13    Teclado  Tecnologia
# 13           14    Monitor  Tecnologia
# 14           15  Impresora  Tecnologia
# 15           16     Laptop  Tecnologia
# 16           17      Mouse  Tecnologia
# 17           18    Teclado  Tecnologia
# 18           19    Monitor  Tecnologia
# 19           20  Impresora  Tecnologia

# %%
ventas = pd.read_csv("ventas.csv")

ventas.to_sql(
    "fact_ventas",
    engine,
    if_exists="append",
    index=False
)

print("Ventas cargadas correctamente")
# Out:
# Ventas cargadas correctamente

# %%
pd.read_sql(
    "SELECT * FROM fact_ventas",
    engine
)
# Out:
#      id_venta  id_cliente  id_producto  id_fecha  cantidad    total
# 0           1           2            4       1.0         9   6938.0
# 1           2           2            1       1.0         5   3860.0
# 2           3           1            1       2.0         9  14021.0
# 3           4           3            1       5.0         8  12023.0
# 4           5           5            1       3.0         3   7532.0
# ..        ...         ...          ...       ...       ...      ...
# 595       596           4            4       NaN         8  14471.0
# 596       597           2            5       NaN         6   9627.0
# 597       598           5            2       NaN         3   1651.0
# 598       599           4            2       NaN         5  12426.0
# 599       600           2            4       NaN         7   1668.0
#
# [600 rows x 6 columns]

# %%
import random
import pandas as pd

ventas = pd.DataFrame({
    "id_cliente": [random.randint(1,5) for _ in range(100)],
    "id_producto": [random.randint(1,5) for _ in range(100)],
    "id_fecha": [random.randint(1,5) for _ in range(100)],
    "cantidad": [random.randint(1,10) for _ in range(100)],
    "total": [random.randint(100,15000) for _ in range(100)]
})

ventas.to_csv("ventas.csv", index=False)

ventas.head()
# Out:
#    id_cliente  id_producto  id_fecha  cantidad  total
# 0           3            3         3         7  14233
# 1           4            4         1         4   3031
# 2           3            1         3         3  10236
# 3           1            5         3         7   8871
# 4           2            4         4        10    933

# %%
fechas = pd.DataFrame({
    "fecha": [
        "2025-06-01",
        "2025-06-02",
        "2025-06-03",
        "2025-06-04",
        "2025-06-05"
    ],
    "mes": [6,6,6,6,6],
    "anio": [2025,2025,2025,2025,2025]
})

fechas.to_sql(
    "dim_fecha",
    engine,
    if_exists="append",
    index=False
)

fechas
# Out:
#         fecha  mes  anio
# 0  2025-06-01    6  2025
# 1  2025-06-02    6  2025
# 2  2025-06-03    6  2025
# 3  2025-06-04    6  2025
# 4  2025-06-05    6  2025

# %%
ventas.to_sql(
    "fact_ventas",
    engine,
    if_exists="append",
    index=False
)

print("Ventas cargadas correctamente")
# Out:
# Ventas cargadas correctamente

# %%
pd.read_sql(
    "SELECT * FROM fact_ventas",
    engine
)
# Out:
#      id_venta  id_cliente  id_producto  id_fecha  cantidad    total
# 0           1           2            4       1.0         9   6938.0
# 1           2           2            1       1.0         5   3860.0
# 2           3           1            1       2.0         9  14021.0
# 3           4           3            1       5.0         8  12023.0
# 4           5           5            1       3.0         3   7532.0
# ..        ...         ...          ...       ...       ...      ...
# 695       696           4            4       2.0         4  12389.0
# 696       697           4            2       5.0         5   2692.0
# 697       698           3            2       5.0         2   6183.0
# 698       699           2            2       4.0         6   8668.0
# 699       700           1            5       5.0         6  10449.0
#
# [700 rows x 6 columns]

# %%
pd.read_sql(
    "SELECT * FROM dim_fecha",
    engine
)
# Out:
#     id_fecha       fecha  mes  anio
# 0          1  2025-06-01    6  2025
# 1          2  2025-06-02    6  2025
# 2          3  2025-06-03    6  2025
# 3          4  2025-06-04    6  2025
# 4          5  2025-06-05    6  2025
# 5          6  2025-06-01    6  2025
# 6          7  2025-06-02    6  2025
# 7          8  2025-06-03    6  2025
# 8          9  2025-06-04    6  2025
# 9         10  2025-06-05    6  2025
# 10        11  2025-06-01    6  2025
# 11        12  2025-06-02    6  2025
# 12        13  2025-06-03    6  2025
# 13        14  2025-06-04    6  2025
# 14        15  2025-06-05    6  2025
# 15        16  2025-06-01    6  2025
# 16        17  2025-06-02    6  2025
# 17        18  2025-06-03    6  2025
# 18        19  2025-06-04    6  2025
# 19        20  2025-06-05    6  2025

# %%
pd.read_sql(
    "SELECT COUNT(*) AS total_ventas FROM fact_ventas",
    engine
)
# Out:
#    total_ventas
# 0           700

# %%
pd.read_sql(
    """
    SELECT COUNT(*) AS total_ventas
    FROM fact_ventas
    """,
    engine
)
# Out:
#    total_ventas
# 0           700

# %%
pd.read_sql(
    """
    SELECT SUM(total) AS ingresos_totales
    FROM fact_ventas
    """,
    engine
)
# Out:
#    ingresos_totales
# 0         5264492.0

# %%
pd.read_sql(
    """
    SELECT AVG(total) AS promedio_venta
    FROM fact_ventas
    """,
    engine
)
# Out:
#    promedio_venta
# 0     7520.702857

# %%
pd.read_sql(
    """
    SELECT 
        id_producto,
        SUM(cantidad) AS total_vendido
    FROM fact_ventas
    GROUP BY id_producto
    ORDER BY total_vendido DESC
    """,
    engine
)
# Out:
#    id_producto  total_vendido
# 0            5            870
# 1            2            868
# 2            4            768
# 3            1            718
# 4            3            716

# %%
import matplotlib.pyplot as plt

consulta = """
SELECT 
    id_producto,
    SUM(cantidad) AS total_vendido
FROM fact_ventas
GROUP BY id_producto
ORDER BY id_producto
"""

df_productos = pd.read_sql(consulta, engine)

plt.bar(df_productos["id_producto"], df_productos["total_vendido"])

plt.title("Productos más vendidos")
plt.xlabel("ID Producto")
plt.ylabel("Cantidad vendida")

plt.show()

# %%
consulta = """
SELECT 
    id_fecha,
    SUM(total) AS ventas_totales
FROM fact_ventas
GROUP BY id_fecha
ORDER BY id_fecha
"""

df_fechas = pd.read_sql(consulta, engine)

plt.plot(df_fechas["id_fecha"], df_fechas["ventas_totales"], marker="o")

plt.title("Ventas totales por fecha")
plt.xlabel("ID Fecha")
plt.ylabel("Total de ventas")

plt.show()

# %%
consulta = """
SELECT
    fv.id_venta,
    dc.nombre,
    dp.producto,
    df.fecha,
    fv.cantidad,
    fv.total
FROM fact_ventas fv
INNER JOIN dim_cliente dc
    ON fv.id_cliente = dc.id_cliente
INNER JOIN dim_producto dp
    ON fv.id_producto = dp.id_producto
INNER JOIN dim_fecha df
    ON fv.id_fecha = df.id_fecha
LIMIT 20;
"""

pd.read_sql(consulta, engine)
# Out:
#     id_venta nombre   producto       fecha  cantidad    total
# 0          1  Maria    Monitor  2025-06-01         9   6938.0
# 1          2  Maria     Laptop  2025-06-01         5   3860.0
# 2          3   Juan     Laptop  2025-06-02         9  14021.0
# 3          4  Pedro     Laptop  2025-06-05         8  12023.0
# 4          5   Luis     Laptop  2025-06-03         3   7532.0
# 5          6    Ana  Impresora  2025-06-04         1   9514.0
# 6          7   Juan  Impresora  2025-06-01         7   3839.0
# 7          8  Pedro    Teclado  2025-06-01         5  10836.0
# 8          9  Maria     Laptop  2025-06-01         9   7258.0
# 9         10   Luis      Mouse  2025-06-01         8  14496.0
# 10        11    Ana  Impresora  2025-06-03         4   8057.0
# 11        12    Ana  Impresora  2025-06-01         4   2855.0
# 12        13   Luis    Monitor  2025-06-05         4  10634.0
# 13        14   Juan    Teclado  2025-06-01         4  11406.0
# 14        15  Pedro     Laptop  2025-06-04         1   4585.0
# 15        16  Pedro  Impresora  2025-06-02        10   9476.0
# 16        17   Luis  Impresora  2025-06-05         7  10432.0
# 17        18    Ana    Teclado  2025-06-05        10   2278.0
# 18        19   Luis    Teclado  2025-06-03         9   7569.0
# 19        20   Juan      Mouse  2025-06-01         3   7033.0

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\angel\\OneDrive\\Documentos\\GitHub\\Extraccion-del-conocimiento\\Notebooks\\SHP_1'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'clientes.csv',
#  'DataWarehouse.ipynb',
#  'productos.csv',
#  'script_dw_ventas.sql',
#  'ventas.csv']
